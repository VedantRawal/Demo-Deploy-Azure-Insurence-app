# %% [markdown]
# # Create a Docker container for API

# %%
# load the dataset from pycaret
from pycaret.datasets import get_data
data = get_data('diamond')
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %%
# initialize setup
from pycaret.regression import *
s = setup(data, target = 'Price', 
          transform_target = True, 
          log_experiment = True, 
          #log_plots = True,
          experiment_name = 'diamond',
         silent = True)
# Out:
# <style type="text/css">
# #T_e28f0_row17_col1, #T_e28f0_row42_col1, #T_e28f0_row56_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e28f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e28f0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e28f0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e28f0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e28f0_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e28f0_row0_col1" class="data row0 col1" >327</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e28f0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e28f0_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e28f0_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_e28f0_row2_col1" class="data row2 col1" >(6000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e28f0_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_e28f0_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e28f0_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_e28f0_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e28f0_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_e28f0_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e28f0_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_e28f0_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e28f0_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_e28f0_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e28f0_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_e28f0_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e28f0_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_e28f0_row9_col1" class="data row9 col1" >(4199, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e28f0_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_e28f0_row10_col1" class="data row10 col1" >(1801, 28)</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e28f0_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_e28f0_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e28f0_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_e28f0_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e28f0_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_e28f0_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e28f0_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_e28f0_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e28f0_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_e28f0_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e28f0_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_e28f0_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e28f0_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_e28f0_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e28f0_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_e28f0_row18_col1" class="data row18 col1" >diamond</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e28f0_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_e28f0_row19_col1" class="data row19 col1" >4904</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e28f0_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_e28f0_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e28f0_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_e28f0_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e28f0_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_e28f0_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e28f0_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_e28f0_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e28f0_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_e28f0_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_e28f0_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_e28f0_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_e28f0_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_e28f0_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_e28f0_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_e28f0_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_e28f0_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_e28f0_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_e28f0_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_e28f0_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e28f0_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_e28f0_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td i

# %%
# train model
lightgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_8bdb0_row10_col0, #T_8bdb0_row10_col1, #T_8bdb0_row10_col2, #T_8bdb0_row10_col3, #T_8bdb0_row10_col4, #T_8bdb0_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8bdb0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bdb0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8bdb0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8bdb0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8bdb0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8bdb0_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_8bdb0_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bdb0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8bdb0_row0_col0" class="data row0 col0" >740.2229</td>
#       <td id="T_8bdb0_row0_col1" class="data row0 col1" >3387560.1277</td>
#       <td id="T_8bdb0_row0_col2" class="data row0 col2" >1840.5326</td>
#       <td id="T_8bdb0_row0_col3" class="data row0 col3" >0.9723</td>
#       <td id="T_8bdb0_row0_col4" class="data row0 col4" >0.0681</td>
#       <td id="T_8bdb0_row0_col5" class="data row0 col5" >0.0497</td>
#     </tr>
#     <tr>
#       <th id="T_8bdb0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8bdb0_row1_col0" class="data row1 col0" >643.3313</td>
#       <td id="T_8bdb0_row1_col1" class="data row1 col1" >1693417.2466</td>
#       <td id="T_8bdb0_row1_col2" class="data row1 col2" >1301.3137</td>
#       <td id="T_8bdb0_row1_col3" class="data row1 col3" >0.9820</td>
#       <td id="T_8bdb0_row1_col4" class="data row1 col4" >0.0656</td>
#       <td id="T_8bdb0_row1_col5" class="data row1 col5" >0.0499</td>
#     </tr>
#     <tr>
#       <th id="T_8bdb0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8bdb0_row2_col0" class="data row2 col0" >668.3230</td>
#       <td id="T_8bdb0_row2_col1" class="data row2 col1" >2346685.4851</td>
#       <td id="T_8bdb0_row2_col2" class="data row2 col2" >1531.8895</td>
#       <td id="T_8bdb0_row2_col3" class="data row2 col3" >0.9738</td>
#       <td id="T_8bdb0_row2_col4" class="data row2 col4" >0.0741</td>
#       <td id="T_8bdb0_row2_col5" class="data row2 col5" >0.0508</td>
#     </tr>
#     <tr>
#       <th id="T_8bdb0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8bdb0_row3_col0" class="data row3 col0" >605.0141</td>
#       <td id="T_8bdb0_row3_col1" class="data row3 col1" >1204311.1657</td>
#       <td id="T_8bdb0_row3_col2" class="data row3 col2" >1097.4111</td>
#       <td id="T_8bdb0_row3_col3" class="data row3 col3" >0.9859</td>
#       <td id="T_8bdb0_row3_col4" class="data row3 col4" >0.0673</td>
#       <td id="T_8bdb0_row3_col5" class="data row3 col5" >0.0506</td>
#     </tr>
#     <tr>
#       <th id="T_8bdb0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8bdb0_row4_col0" class="data row4 col0" >587.5799</td>
#       <td id="T_8bdb0_row4_col1" class="data row4 col1" >1110859.0726</td>
#       <td id="T_8bdb0_row4_col2" class="data row4 col2" >1053.9730</td>
#       <td id="T_8bdb0_row4_col3" class="data row4 col3" >0.9903</td>
#       <td id="T_8bdb0_row4_col4" class="data row4 col4" >0.0603</td>
#       <td id="T_8bdb0_row4_col5" class="data row4 col5" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_8bdb0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8bdb0_row5_col0" class="data row5 col0" >578.9976</td>
#       <td id="T_8bdb0_row5_col1" class="data row5 col1" >1078200.7795</td>
#       <td id="T_8bdb0_row5_col2" class="data row5 col2" >1038.3645</td>
#       <td id="T_8bdb0_row5_col3" class="data row5 col3" >0.9888</td>
#       <td id="T_8bdb0_row5_col4" class="data row5 col4" >0.0612</td>
#       <td id="T_8bdb0_row5_col5" class="data row5 col5" >0.0449</td>
#     </tr>
#     <tr>
#       <th id="T_8bdb0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8bdb0_row6_col0" class="data row6 col0" >683.1194</td>
#       <td id="T_8bdb0_row6_col1" class="data row6 col1" >1817845.1693</td>
#       <td id="T_8bdb0_row6_col2" class="data row6 col2" >1348.2749</td>
#       <td id="T_8bdb0_row6_col3" class="data row6 col3" >0.9818</td>
#       <td id="T_8bdb0_row6_col4" class="data row6 col4" >0.0663</td>
#       <td id="T_8bdb0_row6_col5" class="data row6 col5" >0.0504</td>
#     </tr>
#     <tr>
#       <th id="T_8bdb0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8bdb0_row7_col0" class="data row7 col0" >667.8745</td>
#       <td id="T_8bdb0_row7_col1" class="data row7 col1" >2266613.3904</td>
#       <td id="T_8bdb0_row7_col2" class="data row7 col2" >1505.5276</td>
#       <td id="T_8bdb0_row7_col3" class="data row7 col3" >0.9819</td>
#       <td id="T_8bdb0_row7_col4" class="data row7 col4" >0.0677</td>
#       <td id="T_8bdb0_row7_col5" class="data row7 col5" >0.0496</td>
#     </tr>
#     <tr>
#       <th id="T_8bdb0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8bdb0_row8_col0" class="data row8 col0" >581.9162</td>
#       <td id="T_8bdb0_row8_col1" class="data row8 col1" >1112811.7107</td>
#       <td id="T_8bdb0_row8_col2" class="data row8 col2" >1054.8989</td>
#       <td id="T_8bdb0_row8_col3" class="data row8 col3" >0.9882</td>
#       <td id="T_8bdb0_row8_col4" class="data row8 col4" >0.0611</td>
#       <td id="T_8bdb0_row8_col5" class="data row8 col5" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_8bdb0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8bdb0_row9_col0" class="data row9 col0" >765.4759</td>
#       <td id="T_8bdb0_row9_col1" class="data row9 col1" >4709516.7402</td>
#       <td id="T_8bdb0_row9_col2" class="data row9 col2" >2170.1421</td>
#       <td id="T_8bdb0_row9_col3" class="data row9 col3" >0.9642</td>
#       <td id="T_8bdb0_row9_col4" class="data row9 col4" >0.0761</td>
#       <td id="T_8bdb0_row9_col5" class="data row9 col5" >0.0533</td>
#     </tr>
#     <tr>
#       <th id="T_8bdb0_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_8bdb0_row10_col0" class="data row10 col0" >652.1855</td>
#       <td id="T_8bdb0_row10_col1" class="data row10 col1" >2072782.0888</td>
#       <td id="T_8bdb0_row10_col2" class="data row10 col2" >1394.2328</td>
#       <td id="T_8bdb0_row10_col3" class="data row10 col3" >0.9809</td>
#       <td id="T_8bdb0_row10_col4" class="data row10 col4" >0.0668</td>
#       <td id="T_8bdb0_row10_col5" class="data row10 col5" >0.0491</td>
#     </tr>
#     <tr>
#       <th id="T_8bdb0_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_8bdb0_row11_col0" class="data row11 col0" >62.3061</td>
#       <td id="T_8bdb0_row11_col1" class="data row11 col1" >1122175.9138</td>
#       <td id="T_8bdb0_row11_col2" class="data row11 col2" >359.0223</td>
#       <td id="T_8bdb0_row11_col3" class="data row11 col3" >0.0080</td>
#       <td id="T_8bdb0_row11_col4" class="data row11 col4" >0.0050</td>
#       <td id="T_8bdb0_row11_col5" class="data row11 col5" >0.0025</td>
#     </tr>
#   </tbody>
# </table>

# %%
# create API
create_api(lightgbm, 'my_first_api')
# Out:
# API sucessfully created. This function only creates a POST API, it doesn't run it automatically.
#
# To run your API, please run this command --> !python my_first_api.py

# %%
# create Docker
create_docker('my_first_api')
# Out:
# Writing requirements.txt
# Writing Dockerfile
# Dockerfile and requirements.txt successfully created.
# To build image you have to run --> !docker image build -f "Dockerfile" -t IMAGE_NAME:IMAGE_TAG .

# %%
# !docker image build -f "Dockerfile" -t my_first_image:api_diamond .
# Out:
# [+] Building 0.0s (0/1)
# [+] Building 0.1s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.0s
# [+] Building 0.3s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.2s
# [+] Building 0.4s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.3s
# [+] Building 0.6s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.5s
# [+] Building 0.7s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.6s
# [+] Building 0.9s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.8s
# [+] Building 1.0s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         0.9s
# [+] Building 1.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         1.1s
# [+] Building 1.3s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         1.2s
# [+] Building 1.5s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         1.4s
# [+] Building 1.6s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         1.5s
# [+] Building 1.8s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         1.7s
# [+] Building 1.9s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         1.8s
# [+] Building 2.1s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.0s
# [+] Building 2.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.1s
# [+] Building 2.4s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
# [+] Building 2.5s (4/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
# [+] Building 2.6s (6/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.1s
# [+] Building 2.8s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
# [+] Building 2.9s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                0.1s
# [+] Building 3.1s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                0.3s
# [+] Building 3.2s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                0.4s
# [+] Building 3.4s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                0.6s
# [+] Building 3.5s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                0.7s
# [+] Building 3.7s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                0.9s
# [+] Building 3.8s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                1.1s
# [+] Building 4.0s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                1.2s
# [+] Building 4.1s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                1.4s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [116 kB]
# [+] Building 4.3s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                1.5s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [116 kB]
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [48.4 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB
#  => => # ]
# [+] Building 4.4s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                1.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [48.4 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183
#  => => # kB]
# [+] Building 4.6s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                1.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [48.4 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183
#  => => # kB]
# [+] Building 4.7s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                1.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [48.4 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183
#  => => # kB]
# [+] Building 4.9s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                2.1s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [48.4 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183
#  => => # kB]
# [+] Building 5.0s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                2.2s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [48.4 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183
#  => => # kB]
# [+] Building 5.2s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                2.4s
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.1 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [214 kB]
# [+] Building 5.3s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                2.5s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [214 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [14.6 kB]
# [+] Building 5.5s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                2.7s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [214 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [14.6 kB]
# [+] Building 5.6s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                2.8s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [214 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [14.6 kB]
# [+] Building 5.8s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                3.0s
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8183
#  => => # kB]
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [214 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [14.6 kB]
# [+] Building 5.9s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                3.1s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [214 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [14.6 kB]
#  => => # Fetched 8620 kB in 3s (3181 kB/s)
#  => => # Reading package lists...
# [+] Building 6.0s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                3.2s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [214 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [14.6 kB]
#  => => # Fetched 8620 kB in 3s (3181 kB/s)
#  => => # Reading package lists...
# [+] Building 6.2s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                3.4s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [214 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [14.6 kB]
#  => => # Fetched 8620 kB in 3s (3181 kB/s)
#  => => # Reading package lists...
# [+] Building 6.3s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                3.5s
#  => => # Get:5 http://deb.debian.org/debian-security bullseye-security/main amd
#  => => # 64 Packages [214 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [14.6 kB]
#  => => # Fetched 8620 kB in 3s (3181 kB/s)
#  => => # Reading package lists...
# [+] Building 6.5s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                3.7s
#  => => # 64 Packages [214 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [14.6 kB]
#  => => # Fetched 8620 kB in 3s (3181 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 6.6s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                3.8s
#  => => # 64 Packages [214 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [14.6 kB]
#  => => # Fetched 8620 kB in 3s (3181 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 6.8s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                4.0s
#  => => # 64 Packages [214 kB]
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [14.6 kB]
#  => => # Fetched 8620 kB in 3s (3181 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
# [+] Building 6.9s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                4.1s
#  => => # Get:6 http://deb.debian.org/debian bullseye-updates/main amd64 Package
#  => => # s [14.6 kB]
#  => => # Fetched 8620 kB in 3s (3181 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
#  => => # Building dependency tree...
# [+] Building 7.1s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                4.3s
#  => => # s [14.6 kB]
#  => => # Fetched 8620 kB in 3s (3181 kB/s)
#  => => # Reading package lists...
#  => => # Reading package lists...
#  => => # Building dependency tree...
#  => => # Reading state information...
# [+] Building 7.2s (7/9)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
# ...
#  => exporting to image                                                     9.2s
#  => => exporting layers                                                    9.2s
# [+] Building 159.6s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                     9.3s
#  => => exporting layers                                                    9.3s
# [+] Building 159.8s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                     9.5s
#  => => exporting layers                                                    9.5s
# [+] Building 159.9s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                     9.6s
#  => => exporting layers                                                    9.6s
# [+] Building 160.1s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                     9.8s
#  => => exporting layers                                                    9.8s
# [+] Building 160.2s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                     9.9s
#  => => exporting layers                                                    9.9s
# [+] Building 160.4s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                    10.1s
#  => => exporting layers                                                   10.1s
# [+] Building 160.5s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                    10.2s
#  => => exporting layers                                                   10.2s
# [+] Building 160.7s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                    10.4s
#  => => exporting layers                                                   10.4s
# [+] Building 160.8s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                    10.5s
#  => => exporting layers                                                   10.5s
# [+] Building 161.0s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                    10.7s
#  => => exporting layers                                                   10.7s
# [+] Building 161.1s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                    10.8s
#  => => exporting layers                                                   10.8s
# [+] Building 161.3s (9/10)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                    11.0s
#  => => exporting layers                                                   11.0s
# [+] Building 161.4s (10/10) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 238B                                       0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.8-slim         2.3s
#  => [internal] load build context                                          0.1s
#  => => transferring context: 3.53MB                                        0.1s
#  => [1/5] FROM docker.io/library/python:3.8-slim@sha256:cb29e6c698261ba26  0.0s
#  => CACHED [2/5] WORKDIR /app                                              0.0s
#  => [3/5] ADD . /app                                                       0.3s
#  => [4/5] RUN apt-get update && apt-get install -y libgomp1                5.6s
#  => [5/5] RUN pip install -r requirements.txt                            141.9s
#  => exporting to image                                                    11.1s
#  => => exporting layers                                                   11.0s
#  => => writing image sha256:78ee9864e5eec0c87a98c00194576412f67864e2da2e6  0.0s
#  => => naming to docker.io/library/my_first_image:api_diamond              0.0s

# %%
# !docker images
# Out:
# REPOSITORY               TAG           IMAGE ID       CREATED          SIZE
# my_first_image           api_diamond   78ee9864e5ee   32 seconds ago   1.51GB
# docker/getting-started   latest        3e4394f6b72f   4 weeks ago      47MB

# %%
#http://localhost:8000/docs
